# %%
import os
os.environ['TRANSFORMERS_CACHE'] = os.path.join(os.getcwd(), '..', 'transformers')
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
import pfrl
from textrl import TextRLEnv, TextRLActor, train_agent_with_evaluation
from transformers import AutoModelForCausalLM, AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
import logging
import sys

# %%
logging.basicConfig(level=logging.INFO, stream=sys.stdout, format='')

checkpoint = "gpt2"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForCausalLM.from_pretrained(checkpoint)
model.eval()
model.cuda()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
# sentiment = pipeline('sentiment-analysis',model="cardiffnlp/twitter-roberta-base-sentiment",tokenizer="cardiffnlp/twitter-roberta-base-sentiment",device=0,return_all_scores=True)
sentiment_path_1 = "cardiffnlp/twitter-roberta-base-sentiment" # 'cardiffnlp/twitter-xlm-roberta-base-sentiment'
sentiment_path_2 = 'nlptown/bert-base-multilingual-uncased-sentiment'
sentiment_1 = pipeline('sentiment-analysis',model=sentiment_path_1,tokenizer=sentiment_path_1, top_k=None)
sentiment_2 = pipeline('sentiment-analysis',model=sentiment_path_2,tokenizer=sentiment_path_2, top_k=None)

# %%
def return_score_nlptown(sentence, percent=1):
    scores = sentiment_2(sentence)[0]
    req_score = 0
    for dict_inner in scores:
        if dict_inner['label'] == '1 star':
            req_score += percent * dict_inner['score']
        if dict_inner['label'] == '2 star':
            req_score += (1 - percent) * dict_inner['score']

    return req_score

def return_score_cardiff_roberta_xlm(sentence):
    scores = sentiment_1(sentence)[0]
    req_score = 0
    for dict_inner in scores:
        if dict_inner['label'] == 'negative':
            req_score += 10 * dict_inner['score']
        if dict_inner['label'] == 'positive':
            req_score -= 10 * dict_inner['score']
        if dict_inner['label'] == 'neutral':
            req_score -= 5 * dict_inner['score']

    return req_score

# %%
class MyRLEnv(TextRLEnv):
    def get_reward(self, input_item, predicted_list, finish): # predicted will be the list of predicted token
      reward = 0
      if finish or len(predicted_list[0]) >= self.env_max_length:
        predicted_text = tokenizer.convert_tokens_to_string(predicted_list[0])
        # sentiment classifier
        # reward = sentiment(input_item['input']+predicted_text)[0][0]['score'] * 10
        reward = return_score_cardiff_roberta_xlm(input_item['input']+predicted_text)
        reward = min(reward, return_score_nlptown(input_item['input']+predicted_text))
      return [reward]

# %%
observation_list = [{"input": "Dogecoin is "}]
env = MyRLEnv(
    model, tokenizer, 
    observation_input=observation_list, 
    max_length=25, 
    compare_sample=1
)
actor = TextRLActor(
    env, model, tokenizer, 
    act_deterministically=False, 
    optimizer='adamw',
    temperature=0.8,
    top_k=100,
    top_p=0.85
)
agent = actor.agent_ppo(
    update_interval=2, 
    minibatch_size=2, 
    epochs=10,
    lr=3e-4
)

# %%
test_phrase = "Dogecoin is "
print(test_phrase)
actor.predict({'input': test_phrase})
# Out:
# Dogecoin is
# ['!!! !!! And now they have been hacked by a bunch of idiots, who claim to be the most powerful crypto currency,']

# %%
train_agent_with_evaluation(
    agent,
    env,
    steps=1000,
    eval_n_steps=None,
    eval_n_episodes=1,       
    train_max_episode_len=100,  
    eval_interval=10,
    outdir='checkpoint', 
)
# Out:
# outdir:checkpoint step:27 episode:0 R:0
# statistics:[('average_value', -1.1544421), ('average_entropy', 1.0630808), ('average_value_loss', 0.044745933401300134), ('average_policy_loss', -0.13790720641613008), ('n_updates', 130), ('explained_variance', -29.32518143973233)]
# evaluation episode 0 length:27 R:0
# The best score is updated -3.4028235e+38 -> 0.0
# Saved the agent to checkpoint/best
# outdir:checkpoint step:54 episode:1 R:0
# statistics:[('average_value', -0.55661476), ('average_entropy', 0.554348), ('average_value_loss', 3.0574019629741045e-05), ('average_policy_loss', -5.960464477539063e-09), ('n_updates', 270), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:81 episode:2 R:0
# statistics:[('average_value', -0.45449057), ('average_entropy', 0.66024405), ('average_value_loss', 0.007434408800691017), ('average_policy_loss', -0.1364479586482048), ('n_updates', 400), ('explained_variance', -12.121727398388678)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:108 episode:3 R:0
# statistics:[('average_value', -0.36626735), ('average_entropy', 0.5828616), ('average_value_loss', 0.002342577498893661), ('average_policy_loss', -0.0152191624045372), ('n_updates', 540), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:135 episode:4 R:0
# statistics:[('average_value', -0.29112372), ('average_entropy', 0.4968215), ('average_value_loss', 0.011179837880790728), ('average_policy_loss', -0.02827474683523178), ('n_updates', 670), ('explained_variance', -2100.7425323694097)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:162 episode:5 R:0
# statistics:[('average_value', -0.30955717), ('average_entropy', 0.4424474), ('average_value_loss', 0.016952143666203484), ('average_policy_loss', -0.020116682946681976), ('n_updates', 810), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:189 episode:6 R:0
# statistics:[('average_value', -0.26190376), ('average_entropy', 0.39490363), ('average_value_loss', 0.0018558679277675338), ('average_policy_loss', -0.01645407795906067), ('n_updates', 940), ('explained_variance', 0.6150299553174685)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:216 episode:7 R:0
# statistics:[('average_value', -0.22938138), ('average_entropy', 0.35055616), ('average_value_loss', 9.71048213460346e-05), ('average_policy_loss', 1.7881393432617187e-08), ('n_updates', 1080), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:243 episode:8 R:0
# statistics:[('average_value', -0.21071398), ('average_entropy', 0.3116055), ('average_value_loss', 9.865147688401522e-06), ('average_policy_loss', -8.940696716308593e-09), ('n_updates', 1210), ('explained_variance', 0.8254506988903725)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:270 episode:9 R:0
# statistics:[('average_value', -0.18508883), ('average_entropy', 0.28044495), ('average_value_loss', 7.26560349142158e-05), ('average_policy_loss', 2.0861625671386717e-08), ('n_updates', 1350), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:297 episode:10 R:0
# statistics:[('average_value', -0.16857338), ('average_entropy', 0.25494993), ('average_value_loss', 6.111412443992464e-06), ('average_policy_loss', -1.4901161193847656e-08), ('n_updates', 1480), ('explained_variance', -60.85823849975389)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:324 episode:11 R:0
# statistics:[('average_value', -0.15473083), ('average_entropy', 0.2337041), ('average_value_loss', 2.7192262907460573e-06), ('average_policy_loss', 4.738569259643555e-07), ('n_updates', 1620), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:351 episode:12 R:0
# statistics:[('average_value', -0.14291748), ('average_entropy', 0.21572687), ('average_value_loss', 1.8128751752799487e-06), ('average_policy_loss', 1.4901161193847656e-08), ('n_updates', 1750), ('explained_variance', -87.31253240433404)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:378 episode:13 R:0
# statistics:[('average_value', -0.13090356), ('average_entropy', 0.2003178), ('average_value_loss', 1.88582215724864e-05), ('average_policy_loss', 6.854534149169921e-08), ('n_updates', 1890), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:405 episode:14 R:0
# statistics:[('average_value', -0.12057059), ('average_entropy', 0.18696329), ('average_value_loss', 4.028903993287259e-06), ('average_policy_loss', -4.1723251342773435e-08), ('n_updates', 2020), ('explained_variance', 0.8195933513480954)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:432 episode:15 R:0
# statistics:[('average_value', -0.10422927), ('average_entropy', 0.17527808), ('average_value_loss', 0.0012592758580274221), ('average_policy_loss', 2.9802322387695314e-09), ('n_updates', 2160), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:459 episode:16 R:0
# statistics:[('average_value', -0.08505592), ('average_entropy', 0.16496761), ('average_value_loss', 0.0012950674975400033), ('average_policy_loss', -3.5762786865234374e-08), ('n_updates', 2290), ('explained_variance', 0.8596099073747835)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:486 episode:17 R:0
# statistics:[('average_value', -0.10087449), ('average_entropy', 0.15580276), ('average_value_loss', 0.0018342602821212494), ('average_policy_loss', 2.0861625671386717e-08), ('n_updates', 2430), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:513 episode:18 R:0
# statistics:[('average_value', -0.09662371), ('average_entropy', 0.1476026), ('average_value_loss', 0.00010768896523700278), ('average_policy_loss', 4.470348358154297e-08), ('n_updates', 2560), ('explained_variance', 0.44497213302124083)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:540 episode:19 R:0
# statistics:[('average_value', -0.065479696), ('average_entropy', 0.14022247), ('average_value_loss', 0.004120650811601081), ('average_policy_loss', -5.066394805908203e-07), ('n_updates', 2700), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:567 episode:20 R:0
# statistics:[('average_value', -0.06406504), ('average_entropy', 0.1335452), ('average_value_loss', 8.699297176008258e-05), ('average_policy_loss', 8.940696716308593e-09), ('n_updates', 2830), ('explained_variance', 0.7132413699066789)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:594 episode:21 R:0
# statistics:[('average_value', -0.05957034), ('average_entropy', 0.12747496), ('average_value_loss', 0.0001740293972591911), ('average_policy_loss', -7.748603820800782e-08), ('n_updates', 2970), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:621 episode:22 R:0
# statistics:[('average_value', -0.055557486), ('average_entropy', 0.12193258), ('average_value_loss', 8.193740895876545e-05), ('average_policy_loss', 1.996755599975586e-07), ('n_updates', 3100), ('explained_variance', 0.7617928213319243)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:648 episode:23 R:0
# statistics:[('average_value', -0.057629522), ('average_entropy', 0.11685205), ('average_value_loss', 0.00012160194590478568), ('average_policy_loss', -1.1920928955078126e-08), ('n_updates', 3240), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:675 episode:24 R:0
# statistics:[('average_value', -0.054697063), ('average_entropy', 0.11217797), ('average_value_loss', 1.5901260919531924e-05), ('average_policy_loss', -7.450580596923828e-08), ('n_updates', 3370), ('explained_variance', 0.18845406526385955)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:702 episode:25 R:0
# statistics:[('average_value', -0.055532232), ('average_entropy', 0.10786343), ('average_value_loss', 0.00037159166007256773), ('average_policy_loss', 2.6822090148925782e-08), ('n_updates', 3510), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:729 episode:26 R:0
# statistics:[('average_value', -0.053817913), ('average_entropy', 0.10386849), ('average_value_loss', 1.7502064402281637e-05), ('average_policy_loss', -2.9802322387695312e-08), ('n_updates', 3640), ('explained_variance', -0.24909245446423767)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:756 episode:27 R:0
# statistics:[('average_value', -0.05331634), ('average_entropy', 0.1001589), ('average_value_loss', 2.9320582188034907e-05), ('average_policy_loss', -1.1920928955078126e-08), ('n_updates', 3780), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:783 episode:28 R:0
# statistics:[('average_value', -0.051521447), ('average_entropy', 0.096705146), ('average_value_loss', 4.733027598986972e-05), ('average_policy_loss', 3.874301910400391e-08), ('n_updates', 3910), ('explained_variance', 0.15268196941973655)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:810 episode:29 R:0
# statistics:[('average_value', -0.05317749), ('average_entropy', 0.093481645), ('average_value_loss', 0.00015641161322946573), ('average_policy_loss', -1.7881393432617187e-08), ('n_updates', 4050), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:837 episode:30 R:0
# statistics:[('average_value', -0.05145352), ('average_entropy', 0.090466104), ('average_value_loss', 2.5460408182655936e-05), ('average_policy_loss', 5.066394805908203e-08), ('n_updates', 4180), ('explained_variance', -0.21713899657579838)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:864 episode:31 R:0
# statistics:[('average_value', -0.05073659), ('average_entropy', 0.08763904), ('average_value_loss', 1.2944417975973011e-05), ('average_policy_loss', 0.0), ('n_updates', 4320), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:891 episode:32 R:0
# statistics:[('average_value', -0.048839003), ('average_entropy', 0.08498331), ('average_value_loss', 1.4436287874275421e-05), ('average_policy_loss', -6.854534149169921e-08), ('n_updates', 4450), ('explained_variance', -2.6081083408141645)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:918 episode:33 R:0
# statistics:[('average_value', -0.04721461), ('average_entropy', 0.082483806), ('average_value_loss', 1.4116205282688199e-05), ('average_policy_loss', 2.0861625671386717e-08), ('n_updates', 4590), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:945 episode:34 R:0
# statistics:[('average_value', -0.046123203), ('average_entropy', 0.08012712), ('average_value_loss', 7.155828541840492e-05), ('average_policy_loss', -6.258487701416016e-08), ('n_updates', 4720), ('explained_variance', -0.42164456135063166)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:972 episode:35 R:0
# statistics:[('average_value', -0.04479401), ('average_entropy', 0.07790138), ('average_value_loss', 1.2288232607886584e-05), ('average_policy_loss', -1.4901161193847656e-08), ('n_updates', 4860), ('explained_variance', nan)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:999 episode:36 R:0
# statistics:[('average_value', -0.043387577), ('average_entropy', 0.07579593), ('average_value_loss', 8.542813875074274e-06), ('average_policy_loss', -2.9802322387695314e-09), ('n_updates', 4990), ('explained_variance', -6.657207216476486)]
# evaluation episode 0 length:27 R:0
# outdir:checkpoint step:1000 episode:37 R:0
# statistics:[('average_value', -0.043333158), ('average_entropy', 0.07572014), ('average_value_loss', 3.5244047883864483e-06), ('average_policy_loss', 8.940696716308593e-09), ('n_updates', 5000), ('explained_variance', 0.6669979571621141)]
# evaluation episode 0 length:27 R:0
# Saved the agent to checkpoint/1000_finish
# (<textrl.actor.TextPPO at 0x7ff800073a90>,
#  [{'average_value': -1.1544421,
#    'average_entropy': 1.0630808,
#    'average_value_loss': 0.044745933401300134,
#    'average_policy_loss': -0.13790720641613008,
#    'n_updates': 130,
#    'explained_variance': -29.32518143973233,
#    'eval_score': 0.0},
#   {'average_value': -0.55661476,
#    'average_entropy': 0.554348,
#    'average_value_loss': 3.0574019629741045e-05,
#    'average_policy_loss': -5.960464477539063e-09,
#    'n_updates': 270,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.45449057,
#    'average_entropy': 0.66024405,
#    'average_value_loss': 0.007434408800691017,
#    'average_policy_loss': -0.1364479586482048,
#    'n_updates': 400,
#    'explained_variance': -12.121727398388678,
#    'eval_score': 0.0},
#   {'average_value': -0.36626735,
#    'average_entropy': 0.5828616,
#    'average_value_loss': 0.002342577498893661,
#    'average_policy_loss': -0.0152191624045372,
#    'n_updates': 540,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.29112372,
#    'average_entropy': 0.4968215,
#    'average_value_loss': 0.011179837880790728,
#    'average_policy_loss': -0.02827474683523178,
#    'n_updates': 670,
#    'explained_variance': -2100.7425323694097,
#    'eval_score': 0.0},
#   {'average_value': -0.30955717,
#    'average_entropy': 0.4424474,
#    'average_value_loss': 0.016952143666203484,
#    'average_policy_loss': -0.020116682946681976,
#    'n_updates': 810,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.26190376,
#    'average_entropy': 0.39490363,
#    'average_value_loss': 0.0018558679277675338,
#    'average_policy_loss': -0.01645407795906067,
#    'n_updates': 940,
#    'explained_variance': 0.6150299553174685,
#    'eval_score': 0.0},
#   {'average_value': -0.22938138,
#    'average_entropy': 0.35055616,
#    'average_value_loss': 9.71048213460346e-05,
#    'average_policy_loss': 1.7881393432617187e-08,
#    'n_updates': 1080,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.21071398,
#    'average_entropy': 0.3116055,
#    'average_value_loss': 9.865147688401522e-06,
#    'average_policy_loss': -8.940696716308593e-09,
#    'n_updates': 1210,
#    'explained_variance': 0.8254506988903725,
#    'eval_score': 0.0},
#   {'average_value': -0.18508883,
#    'average_entropy': 0.28044495,
#    'average_value_loss': 7.26560349142158e-05,
#    'average_policy_loss': 2.0861625671386717e-08,
#    'n_updates': 1350,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.16857338,
#    'average_entropy': 0.25494993,
#    'average_value_loss': 6.111412443992464e-06,
#    'average_policy_loss': -1.4901161193847656e-08,
#    'n_updates': 1480,
#    'explained_variance': -60.85823849975389,
#    'eval_score': 0.0},
#   {'average_value': -0.15473083,
#    'average_entropy': 0.2337041,
#    'average_value_loss': 2.7192262907460573e-06,
#    'average_policy_loss': 4.738569259643555e-07,
#    'n_updates': 1620,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.14291748,
#    'average_entropy': 0.21572687,
#    'average_value_loss': 1.8128751752799487e-06,
#    'average_policy_loss': 1.4901161193847656e-08,
#    'n_updates': 1750,
#    'explained_variance': -87.31253240433404,
#    'eval_score': 0.0},
#   {'average_value': -0.13090356,
#    'average_entropy': 0.2003178,
#    'average_value_loss': 1.88582215724864e-05,
#    'average_policy_loss': 6.854534149169921e-08,
#    'n_updates': 1890,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.12057059,
#    'average_entropy': 0.18696329,
#    'average_value_loss': 4.028903993287259e-06,
#    'average_policy_loss': -4.1723251342773435e-08,
#    'n_updates': 2020,
#    'explained_variance': 0.8195933513480954,
#    'eval_score': 0.0},
#   {'average_value': -0.10422927,
#    'average_entropy': 0.17527808,
#    'average_value_loss': 0.0012592758580274221,
#    'average_policy_loss': 2.9802322387695314e-09,
#    'n_updates': 2160,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.08505592,
#    'average_entropy': 0.16496761,
#    'average_value_loss': 0.0012950674975400033,
#    'average_policy_loss': -3.5762786865234374e-08,
#    'n_updates': 2290,
#    'explained_variance': 0.8596099073747835,
#    'eval_score': 0.0},
#   {'average_value': -0.10087449,
#    'average_entropy': 0.15580276,
#    'average_value_loss': 0.0018342602821212494,
#    'average_policy_loss': 2.0861625671386717e-08,
#    'n_updates': 2430,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.09662371,
#    'average_entropy': 0.1476026,
#    'average_value_loss': 0.00010768896523700278,
#    'average_policy_loss': 4.470348358154297e-08,
#    'n_updates': 2560,
#    'explained_variance': 0.44497213302124083,
#    'eval_score': 0.0},
#   {'average_value': -0.065479696,
#    'average_entropy': 0.14022247,
#    'average_value_loss': 0.004120650811601081,
#    'average_policy_loss': -5.066394805908203e-07,
#    'n_updates': 2700,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.06406504,
#    'average_entropy': 0.1335452,
#    'average_value_loss': 8.699297176008258e-05,
#    'average_policy_loss': 8.940696716308593e-09,
#    'n_updates': 2830,
#    'explained_variance': 0.7132413699066789,
#    'eval_score': 0.0},
#   {'average_value': -0.05957034,
#    'average_entropy': 0.12747496,
#    'average_value_loss': 0.0001740293972591911,
#    'average_policy_loss': -7.748603820800782e-08,
#    'n_updates': 2970,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.055557486,
#    'average_entropy': 0.12193258,
#    'average_value_loss': 8.193740895876545e-05,
#    'average_policy_loss': 1.996755599975586e-07,
#    'n_updates': 3100,
#    'explained_variance': 0.7617928213319243,
#    'eval_score': 0.0},
#   {'average_value': -0.057629522,
#    'average_entropy': 0.11685205,
#    'average_value_loss': 0.00012160194590478568,
#    'average_policy_loss': -1.1920928955078126e-08,
#    'n_updates': 3240,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.054697063,
#    'average_entropy': 0.11217797,
#    'average_value_loss': 1.5901260919531924e-05,
#    'average_policy_loss': -7.450580596923828e-08,
#    'n_updates': 3370,
#    'explained_variance': 0.18845406526385955,
#    'eval_score': 0.0},
#   {'average_value': -0.055532232,
#    'average_entropy': 0.10786343,
#    'average_value_loss': 0.00037159166007256773,
#    'average_policy_loss': 2.6822090148925782e-08,
#    'n_updates': 3510,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.053817913,
#    'average_entropy': 0.10386849,
#    'average_value_loss': 1.7502064402281637e-05,
#    'average_policy_loss': -2.9802322387695312e-08,
#    'n_updates': 3640,
#    'explained_variance': -0.24909245446423767,
#    'eval_score': 0.0},
#   {'average_value': -0.05331634,
#    'average_entropy': 0.1001589,
#    'average_value_loss': 2.9320582188034907e-05,
#    'average_policy_loss': -1.1920928955078126e-08,
#    'n_updates': 3780,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.051521447,
#    'average_entropy': 0.096705146,
#    'average_value_loss': 4.733027598986972e-05,
#    'average_policy_loss': 3.874301910400391e-08,
#    'n_updates': 3910,
#    'explained_variance': 0.15268196941973655,
#    'eval_score': 0.0},
#   {'average_value': -0.05317749,
#    'average_entropy': 0.093481645,
#    'average_value_loss': 0.00015641161322946573,
#    'average_policy_loss': -1.7881393432617187e-08,
#    'n_updates': 4050,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.05145352,
#    'average_entropy': 0.090466104,
#    'average_value_loss': 2.5460408182655936e-05,
#    'average_policy_loss': 5.066394805908203e-08,
#    'n_updates': 4180,
#    'explained_variance': -0.21713899657579838,
#    'eval_score': 0.0},
#   {'average_value': -0.05073659,
#    'average_entropy': 0.08763904,
#    'average_value_loss': 1.2944417975973011e-05,
#    'average_policy_loss': 0.0,
#    'n_updates': 4320,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.048839003,
#    'average_entropy': 0.08498331,
#    'average_value_loss': 1.4436287874275421e-05,
#    'average_policy_loss': -6.854534149169921e-08,
#    'n_updates': 4450,
#    'explained_variance': -2.6081083408141645,
#    'eval_score': 0.0},
#   {'average_value': -0.04721461,
#    'average_entropy': 0.082483806,
#    'average_value_loss': 1.4116205282688199e-05,
#    'average_policy_loss': 2.0861625671386717e-08,
#    'n_updates': 4590,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.046123203,
#    'average_entropy': 0.08012712,
#    'average_value_loss': 7.155828541840492e-05,
#    'average_policy_loss': -6.258487701416016e-08,
#    'n_updates': 4720,
#    'explained_variance': -0.42164456135063166,
#    'eval_score': 0.0},
#   {'average_value': -0.04479401,
#    'average_entropy': 0.07790138,
#    'average_value_loss': 1.2288232607886584e-05,
#    'average_policy_loss': -1.4901161193847656e-08,
#    'n_updates': 4860,
#    'explained_variance': nan,
#    'eval_score': 0.0},
#   {'average_value': -0.043387577,
#    'average_entropy': 0.07579593,
#    'average_value_loss': 8.542813875074274e-06,
#    'average_policy_loss': -2.9802322387695314e-09,
#    'n_updates': 4990,
#    'explained_variance': -6.657207216476486,
#    'eval_score': 0.0},
#   {'average_value': -0.043333158,
#    'average_entropy': 0.07572014,
#    'average_value_loss': 3.5244047883864483e-06,
#    'average_policy_loss': 8.940696716308593e-09,
#    'n_updates': 5000,
#    'explained_variance': 0.6669979571621141,
#    'eval_score': 0.0}])

# %%
agent.load('./checkpoint/best')
print(observation_list[0])
actor.predict(observation_list[0])
# Out:
# {'input': 'Dogecoin is '}
# ['urchins just just like it just just just just just just just just just just just just just just just just just just just']
